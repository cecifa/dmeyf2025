# %% [markdown]
# # Modelo 1 - hacer optimización en CSV con lag y delta lag y despues correr cada semilla

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dmeyf" /content/buckets/b1


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/dmeyf2025-e4a2/competencia_01_crudo.csv"
archivo_destino="/content/datasets/competencia_01_crudo.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/competencia_01_crudo.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ## Generacion de la clase_ternaria

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202101   BAJA+1            622
# 2  202101   BAJA+2            825
# 3  202101   CONTINUA       160080
# 4  202102   BAJA+1            831
# 5  202102   BAJA+2           1032
# 6  202102   CONTINUA       160292
# 7  202103   BAJA+1           1039
# 8  202103   BAJA+2            951
# 9  202103   CONTINUA       161119
# 10 202104   BAJA+1            955
# 11 202104   BAJA+2           1130
# 12 202104   CONTINUA       161333
# 13 202105   NA             162783
# 14 202105   BAJA+1           1134
# 15 202106   NA             164313

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Oct 10 09:20:05 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  725853 38.8   1454465    77.7   1454465   77.7
# Vcells 1422186 10.9 169515412  1293.3 211569292 1614.2

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %% [markdown]
# Esta parte lleva varios minutos la primera vez en Google Colab

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: parallel
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings
#
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4950 #IR CAMBIANDO
PARAM$semilla_primigenia <- 202513 #PROBAR SEMILLAS DISTINTAS (202513	202519	202529	202543	202549)

# %%
# training y future AJUSTADO
PARAM$train <- c(202102)          # Mes de validación
PARAM$train_final <- c(202101, 202102, 202103, 202104)
PARAM$future <- c(202106)
PARAM$semilla_kaggle <- 314159
PARAM$cortes <- seq(10000, 12000, by= 500) # LO CAMBIE POR RECOMENDAC DEL PROFE

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.1

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L)   ,
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed, "L'Ecuyer-CMRG")

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# iniciliazo el dataset de realidad, para medir ganancia
realidad_inicializar <- function( pfuture, pparam) {

  # datos para verificar la ganancia
  drealidad <- pfuture[, list(numero_de_cliente, foto_mes, clase_ternaria)]

  particionar(drealidad,
    division= c(3, 7),
    agrupa= "clase_ternaria",
    seed= PARAM$semilla_kaggle
  )

  return( drealidad )
}

# %%
# evaluo ganancia en los datos de la realidad

realidad_evaluar <- function( prealidad, pprediccion) {

  prealidad[ pprediccion,
    on= c("numero_de_cliente", "foto_mes"),
    predicted:= i.Predicted
  ]

  tbl <- prealidad[, list("qty"=.N), list(fold, predicted, clase_ternaria)]

  res <- list()
  res$public  <- tbl[fold==1 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.3
  res$private <- tbl[fold==2 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.7
  res$total <- tbl[predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]

  prealidad[, predicted:=NULL]
  return( res )
}

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset CON INFO DE LAG Y DELTA LAG 1 Y 2 ######
dataset <- fread("/content/buckets/b1/datasets/competencia_01_lags_OK.csv.gz", stringsAsFactors= TRUE)

# %%
# Muestra una lista de todos los nombres de las columnas
print(colnames(dataset))
# Out:
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"
# [156] "active_quarter_lag_1"
# [157] "active_quarter_delta_lag_1"
# [158] "active_quarter_lag_2"
# [159] "active_quarter_delta_lag_2"
# [160] "cliente_vip_lag_1"
# [161] "cliente_vip_delta_lag_1"
# [162] "cliente_vip_lag_2"
# [163] "cliente_vip_delta_lag_2"
# [164] "internet_lag_1"
# [165] "internet_delta_lag_1"
# [166] "internet_lag_2"
# [167] "internet_delta_lag_2"
# [168] "cliente_edad_lag_1"
# [169] "cliente_edad_delta_lag_1"
# [170] "cliente_edad_lag_2"
# [171] "cliente_edad_delta_lag_2"
# [172] "cliente_antiguedad_lag_1"
# [173] "cliente_antiguedad_delta_lag_1"
# [174] "cliente_antiguedad_lag_2"
# [175] "cliente_antiguedad_delta_lag_2"
# [176] "mrentabilidad_lag_1"
# [177] "mrentabilidad_delta_lag_1"
# [178] "mrentabilidad_lag_2"
# [179] "mrentabilidad_delta_lag_2"
# [180] "mrentabilidad_annual_lag_1"
# [181] "mrentabilidad_annual_delta_lag_1"
# [182] "mrentabilidad_annual_lag_2"
# [183] "mrentabilidad_annual_delta_lag_2"
# [184] "mcomisiones_lag_1"
# [185] "mcomisiones_delta_lag_1"
# [186] "mcomisiones_lag_2"
# [187] "mcomisiones_delta_lag_2"
# [188] "mactivos_margen_lag_1"
# [189] "mactivos_margen_delta_lag_1"
# [190] "mactivos_margen_lag_2"
# [191] "mactivos_margen_delta_lag_2"
# [192] "mpasivos_margen_lag_1"
# [193] "mpasivos_margen_delta_lag_1"
# [194] "mpasivos_margen_lag_2"
# [195] "mpasivos_margen_delta_lag_2"
# [196] "cproductos_lag_1"
# [197] "cproductos_delta_lag_1"
# [198] "cproductos_lag_2"
# [199] "cproductos_delta_lag_2"
# [200] "tcuentas_lag_1"
# [201] "tcuentas_delta_lag_1"
# [202] "tcuentas_lag_2"
# [203] "tcuentas_delta_lag_2"
# [204] "ccuenta_corriente_lag_1"
# [205] "ccuenta_corriente_delta_lag_1"
# [206] "ccuenta_corriente_lag_2"
# [207] "ccuenta_corriente_delta_lag_2"
# [208] "mcuenta_corriente_adicional_lag_1"
# [209] "mcuenta_corriente_adicional_delta_lag_1"
# [210] "mcuenta_corriente_adicional_lag_2"
# [211] "mcuenta_corriente_adicional_delta_lag_2"
# [212] "mcuenta_corriente_lag_1"
# [213] "mcuenta_corriente_delta_lag_1"
# [214] "mcuenta_corriente_lag_2"
# [215] "mcuenta_corriente_delta_lag_2"
# [216] "ccaja_ahorro_lag_1"
# [217] "ccaja_ahorro_delta_lag_1"
# [218] "ccaja_ahorro_lag_2"
# [219] "ccaja_ahorro_delta_lag_2"
# [220] "mcaja_ahorro_lag_1"
# [221] "mcaja_ahorro_delta_lag_1"
# [222] "mcaja_ahorro_lag_2"
# [223] "mcaja_ahorro_delta_lag_2"
# [224] "mcaja_ahorro_adicional_lag_1"
# [225] "mcaja_ahorro_adicional_delta_lag_1"
# [226] "mcaja_ahorro_adicional_lag_2"
# [227] "mcaja_ahorro_adicional_delta_lag_2"
# [228] "mcaja_ahorro_dolares_lag_1"
# [229] "mcaja_ahorro_dolares_delta_lag_1"
# [230] "mcaja_ahorro_dolares_lag_2"
# [231] "mcaja_ahorro_dolares_delta_lag_2"
# [232] "cdescubierto_preacordado_lag_1"
# [233] "cdescubierto_preacordado_delta_lag_1"
# [234] "cdescubierto_preacordado_lag_2"
# [235] "cdescubierto_preacordado_delta_lag_2"
# [236] "mcuentas_saldo_lag_1"
# [237] "mcuentas_saldo_delta_lag_1"
# [238] "mcuentas_saldo_lag_2"
# [239] "mcuentas_saldo_delta_lag_2"
# [240] "ctarjeta_debito_lag_1"
# [241] "ctarjeta_debito_delta_lag_1"
# [242] "ctarjeta_debito_lag_2"
# [243] "ctarjeta_debito_delta_lag_2"
# [244] "ctarjeta_debito_transacciones_lag_1"
# [245] "ctarjeta_debito_transacciones_delta_lag_1"
# [246] "ctarjeta_debito_transacciones_lag_2"
# [247] "ctarjeta_debito_transacciones_delta_lag_2"
# [248] "mautoservicio_lag_1"
# [249] "mautoservicio_delta_lag_1"
# [250] "mautoservicio_lag_2"
# [251] "mautoservicio_delta_lag_2"
# [252] "ctarjeta_visa_lag_1"
# [253] "ctarjeta_visa_delta_lag_1"
# [254] "ctarjeta_visa_lag_2"
# [255] "ctarjeta_visa_delta_lag_2"
# [256] "ctarjeta_visa_transacciones_lag_1"
# [257] "ctarjeta_visa_transacciones_delta_lag_1"
# [258] "ctarjeta_visa_transacciones_lag_2"
# [259] "ctarjeta_visa_transacciones_delta_lag_2"
# [260] "mtarjeta_visa_consumo_lag_1"
# [261] "mtarjeta_visa_consumo_delta_lag_1"
# [262] "mtarjeta_visa_consumo_lag_2"
# [263] "mtarjeta_visa_consumo_delta_lag_2"
# [264] "ctarjeta_master_lag_1"
# [265] "ctarjeta_master_delta_lag_1"
# [266] "ctarjeta_master_lag_2"
# [267] "ctarjeta_master_delta_lag_2"
# [268] "ctarjeta_master_transacciones_lag_1"
# [269] "ctarjeta_master_transacciones_delta_lag_1"
# [270] "ctarjeta_master_transacciones_lag_2"
# [271] "ctarjeta_master_transacciones_delta_lag_2"
# [272] "mtarjeta_master_consumo_lag_1"
# [273] "mtarjeta_master_consumo_delta_lag_1"
# [274] "mtarjeta_master_consumo_lag_2"
# [275] "mtarjeta_master_consumo_delta_lag_2"
# [276] "cprestamos_personales_lag_1"
# [277] "cprestamos_personales_delta_lag_1"
# [278] "cprestamos_personales_lag_2"
# [279] "cprestamos_personales_delta_lag_2"
# [280] "mprestamos_personales_lag_1"
# [281] "mprestamos_personales_delta_lag_1"
# [282] "mprestamos_personales_lag_2"
# [283] "mprestamos_personales_delta_lag_2"
# [284] "cprestamos_prendarios_lag_1"
# [285] "cprestamos_prendarios_delta_lag_1"
# [286] "cprestamos_prendarios_lag_2"
# [287] "cprestamos_prendarios_delta_lag_2"
# [288] "mprestamos_prendarios_lag_1"
# [289] "mprestamos_prendarios_delta_lag_1"
# [290] "mprestamos_prendarios_lag_2"
# [291] "mprestamos_prendarios_delta_lag_2"
# [292] "cprestamos_hipotecarios_lag_1"
# [293] "cprestamos_hipotecarios_delta_lag_1"
# [294] "cprestamos_hipotecarios_lag_2"
# [295] "cprestamos_hipotecarios_delta_lag_2"
# [296] "mprestamos_hipotecarios_lag_1"
# [297] "mprestamos_hipotecarios_delta_lag_1"
# [298] "mprestamos_hipotecarios_lag_2"
# [299] "mprestamos_hipotecarios_delta_lag_2"
# [300] "cplazo_fijo_lag_1"
# [301] "cplazo_fijo_delta_lag_1"
# [302] "cplazo_fijo_lag_2"
# [303] "cplazo_fijo_delta_lag_2"
# [304] "mplazo_fijo_dolares_lag_1"
# [305] "mplazo_fijo_dolares_delta_lag_1"
# [306] "mplazo_fijo_dolares_lag_2"
# [307] "mplazo_fijo_dolares_delta_lag_2"
# [308] "mplazo_fijo_pesos_lag_1"
# [309] "mplazo_fijo_pesos_delta_lag_1"
# [310] "mplazo_fijo_pesos_lag_2"
# [311] "mplazo_fijo_pesos_delta_lag_2"
# [312] "cinversion1_lag_1"
# [313] "cinversion1_delta_lag_1"
# [314] "cinversion1_lag_2"
# [315] "cinversion1_delta_lag_2"
# [316] "minversion1_pesos_lag_1"
# [317] "minversion1_pesos_delta_lag_1"
# [318] "minversion1_pesos_lag_2"
# [319] "minversion1_pesos_delta_lag_2"
# [320] "minversion1_dolares_lag_1"
# [321] "minversion1_dolares_delta_lag_1"
# [322] "minversion1_dolares_lag_2"
# [323] "minversion1_dolares_delta_lag_2"
# [324] "cinversion2_lag_1"
# [325] "cinversion2_delta_lag_1"
# [326] "cinversion2_lag_2"
# [327] "cinversion2_delta_lag_2"
# [328] "minversion2_lag_1"
# [329] "minversion2_delta_lag_1"
# [330] "minversion2_lag_2"
# [331] "minversion2_delta_lag_2"
# [332] "cseguro_vida_lag_1"
# [333] "cseguro_vida_delta_lag_1"
# [334] "cseguro_vida_lag_2"
# [335] "cseguro_vida_delta_lag_2"
# [336] "cseguro_auto_lag_1"
# [337] "cseguro_auto_delta_lag_1"
# [338] "cseguro_auto_lag_2"
# [339] "cseguro_auto_delta_lag_2"
# [340] "cseguro_vivienda_lag_1"
# [341] "cseguro_vivienda_delta_lag_1"
# [342] "cseguro_vivienda_lag_2"
# [343] "cseguro_vivienda_delta_lag_2"
# [344] "cseguro_accidentes_personales_lag_1"
# [345] "cseguro_accidentes_personales_delta_lag_1"
# [346] "cseguro_accidentes_personales_lag_2"
# [347] "cseguro_accidentes_personales_delta_lag_2"
# [348] "ccaja_seguridad_lag_1"
# [349] "ccaja_seguridad_delta_lag_1"
# [350] "ccaja_seguridad_lag_2"
# [351] "ccaja_seguridad_delta_lag_2"
# [352] "cpayroll_trx_lag_1"
# [353] "cpayroll_trx_delta_lag_1"
# [354] "cpayroll_trx_lag_2"
# [355] "cpayroll_trx_delta_lag_2"
# [356] "mpayroll_lag_1"
# [357] "mpayroll_delta_lag_1"
# [358] "mpayroll_lag_2"
# [359] "mpayroll_delta_lag_2"
# [360] "mpayroll2_lag_1"
# [361] "mpayroll2_delta_lag_1"
# [362] "mpayroll2_lag_2"
# [363] "mpayroll2_delta_lag_2"
# [364] "cpayroll2_trx_lag_1"
# [365] "cpayroll2_trx_delta_lag_1"
# [366] "cpayroll2_trx_lag_2"
# [367] "cpayroll2_trx_delta_lag_2"
# [368] "ccuenta_debitos_automaticos_lag_1"
# [369] "ccuenta_debitos_automaticos_delta_lag_1"
# [370] "ccuenta_debitos_automaticos_lag_2"
# [371] "ccuenta_debitos_automaticos_delta_lag_2"
# [372] "mcuenta_debitos_automaticos_lag_1"
# [373] "mcuenta_debitos_automaticos_delta_lag_1"
# [374] "mcuenta_debitos_automaticos_lag_2"
# [375] "mcuenta_debitos_automaticos_delta_lag_2"
# [376] "ctarjeta_visa_debitos_automaticos_lag_1"
# [377] "ctarjeta_visa_debitos_automaticos_delta_lag_1"
# [378] "ctarjeta_visa_debitos_automaticos_lag_2"
# [379] "ctarjeta_visa_debitos_automaticos_delta_lag_2"
# [380] "mttarjeta_visa_debitos_automaticos_lag_1"
# [381] "mttarjeta_visa_debitos_automaticos_delta_lag_1"
# [382] "mttarjeta_visa_debitos_automaticos_lag_2"
# [383] "mttarjeta_visa_debitos_automaticos_delta_lag_2"
# [384] "ctarjeta_master_debitos_automaticos_lag_1"
# [385] "ctarjeta_master_debitos_automaticos_delta_lag_1"
# [386] "ctarjeta_master_debitos_automaticos_lag_2"
# [387] "ctarjeta_master_debitos_automaticos_delta_lag_2"
# [388] "mttarjeta_master_debitos_automaticos_lag_1"
# [389] "mttarjeta_master_debitos_automaticos_delta_lag_1"
# [390] "mttarjeta_master_debitos_automaticos_lag_2"
# [391] "mttarjeta_master_debitos_automaticos_delta_lag_2"
# [392] "cpagodeservicios_lag_1"
# [393] "cpagodeservicios_delta_lag_1"
# [394] "cpagodeservicios_lag_2"
# [395] "cpagodeservicios_delta_lag_2"
# [396] "mpagodeservicios_lag_1"
# [397] "mpagodeservicios_delta_lag_1"
# [398] "mpagodeservicios_lag_2"
# [399] "mpagodeservicios_delta_lag_2"
# [400] "cpagomiscuentas_lag_1"
# [401] "cpagomiscuentas_delta_lag_1"
# [402] "cpagomiscuentas_lag_2"
# [403] "cpagomiscuentas_delta_lag_2"
# [404] "mpagomiscuentas_lag_1"
# [405] "mpagomiscuentas_delta_lag_1"
# [406] "mpagomiscuentas_lag_2"
# [407] "mpagomiscuentas_delta_lag_2"
# [408] "ccajeros_propios_descuentos_lag_1"
# [409] "ccajeros_propios_descuentos_delta_lag_1"
# [410] "ccajeros_propios_descuentos_lag_2"
# [411] "ccajeros_propios_descuentos_delta_lag_2"
# [412] "mcajeros_propios_descuentos_lag_1"
# [413] "mcajeros_propios_descuentos_delta_lag_1"
# [414] "mcajeros_propios_descuentos_lag_2"
# [415] "mcajeros_propios_descuentos_delta_lag_2"
# [416] "ctarjeta_visa_descuentos_lag_1"
# [417] "ctarjeta_visa_descuentos_delta_lag_1"
# [418] "ctarjeta_visa_descuentos_lag_2"
# [419] "ctarjeta_visa_descuentos_delta_lag_2"
# [420] "mtarjeta_visa_descuentos_lag_1"
# [421] "mtarjeta_visa_descuentos_delta_lag_1"
# [422] "mtarjeta_visa_descuentos_lag_2"
# [423] "mtarjeta_visa_descuentos_delta_lag_2"
# [424] "ctarjeta_master_descuentos_lag_1"
# [425] "ctarjeta_master_descuentos_delta_lag_1"
# [426] "ctarjeta_master_descuentos_lag_2"
# [427] "ctarjeta_master_descuentos_delta_lag_2"
# [428] "mtarjeta_master_descuentos_lag_1"
# [429] "mtarjeta_master_descuentos_delta_lag_1"
# [430] "mtarjeta_master_descuentos_lag_2"
# [431] "mtarjeta_master_descuentos_delta_lag_2"
# [432] "ccomisiones_mantenimiento_lag_1"
# [433] "ccomisiones_mantenimiento_delta_lag_1"
# [434] "ccomisiones_mantenimiento_lag_2"
# [435] "ccomisiones_mantenimiento_delta_lag_2"
# [436] "mcomisiones_mantenimiento_lag_1"
# [437] "mcomisiones_mantenimiento_delta_lag_1"
# [438] "mcomisiones_mantenimiento_lag_2"
# [439] "mcomisiones_mantenimiento_delta_lag_2"
# [440] "ccomisiones_otras_lag_1"
# [441] "ccomisiones_otras_delta_lag_1"
# [442] "ccomisiones_otras_lag_2"
# [443] "ccomisiones_otras_delta_lag_2"
# [444] "mcomisiones_otras_lag_1"
# [445] "mcomisiones_otras_delta_lag_1"
# [446] "mcomisiones_otras_lag_2"
# [447] "mcomisiones_otras_delta_lag_2"
# [448] "cforex_lag_1"
# [449] "cforex_delta_lag_1"
# [450] "cforex_lag_2"
# [451] "cforex_delta_lag_2"
# [452] "cforex_buy_lag_1"
# [453] "cforex_buy_delta_lag_1"
# [454] "cforex_buy_lag_2"
# [455] "cforex_buy_delta_lag_2"
# [456] "mforex_buy_lag_1"
# [457] "mforex_buy_delta_lag_1"
# [458] "mforex_buy_lag_2"
# [459] "mforex_buy_delta_lag_2"
# [460] "cforex_sell_lag_1"
# [461] "cforex_sell_delta_lag_1"
# [462] "cforex_sell_lag_2"
# [463] "cforex_sell_delta_lag_2"
# [464] "mforex_sell_lag_1"
# [465] "mforex_sell_delta_lag_1"
# [466] "mforex_sell_lag_2"
# [467] "mforex_sell_delta_lag_2"
# [468] "ctransferencias_recibidas_lag_1"
# [469] "ctransferencias_recibidas_delta_lag_1"
# [470] "ctransferencias_recibidas_lag_2"
# [471] "ctransferencias_recibidas_delta_lag_2"
# [472] "mtransferencias_recibidas_lag_1"
# [473] "mtransferencias_recibidas_delta_lag_1"
# [474] "mtransferencias_recibidas_lag_2"
# [475] "mtransferencias_recibidas_delta_lag_2"
# [476] "ctransferencias_emitidas_lag_1"
# [477] "ctransferencias_emitidas_delta_lag_1"
# [478] "ctransferencias_emitidas_lag_2"
# [479] "ctransferencias_emitidas_delta_lag_2"
# [480] "mtransferencias_emitidas_lag_1"
# [481] "mtransferencias_emitidas_delta_lag_1"
# [482] "mtransferencias_emitidas_lag_2"
# [483] "mtransferencias_emitidas_delta_lag_2"
# [484] "cextraccion_autoservicio_lag_1"
# [485] "cextraccion_autoservicio_delta_lag_1"
# [486] "cextraccion_autoservicio_lag_2"
# [487] "cextraccion_autoservicio_delta_lag_2"
# [488] "mextraccion_autoservicio_lag_1"
# [489] "mextraccion_autoservicio_delta_lag_1"
# [490] "mextraccion_autoservicio_lag_2"
# [491] "mextraccion_autoservicio_delta_lag_2"
# [492] "ccheques_depositados_lag_1"
# [493] "ccheques_depositados_delta_lag_1"
# [494] "ccheques_depositados_lag_2"
# [495] "ccheques_depositados_delta_lag_2"
# [496] "mcheques_depositados_lag_1"
# [497] "mcheques_depositados_delta_lag_1"
# [498] "mcheques_depositados_lag_2"
# [499] "mcheques_depositados_delta_lag_2"
# [500] "ccheques_emitidos_lag_1"
# [501] "ccheques_emitidos_delta_lag_1"
# [502] "ccheques_emitidos_lag_2"
# [503] "ccheques_emitidos_delta_lag_2"
# [504] "mcheques_emitidos_lag_1"
# [505] "mcheques_emitidos_delta_lag_1"
# [506] "mcheques_emitidos_lag_2"
# [507] "mcheques_emitidos_delta_lag_2"
# [508] "ccheques_depositados_rechazados_lag_1"
# [509] "ccheques_depositados_rechazados_delta_lag_1"
# [510] "ccheques_depositados_rechazados_lag_2"
# [511] "ccheques_depositados_rechazados_delta_lag_2"
# [512] "mcheques_depositados_rechazados_lag_1"
# [513] "mcheques_depositados_rechazados_delta_lag_1"
# [514] "mcheques_depositados_rechazados_lag_2"
# [515] "mcheques_depositados_rechazados_delta_lag_2"
# [516] "ccheques_emitidos_rechazados_lag_1"
# [517] "ccheques_emitidos_rechazados_delta_lag_1"
# [518] "ccheques_emitidos_rechazados_lag_2"
# [519] "ccheques_emitidos_rechazados_delta_lag_2"
# [520] "mcheques_emitidos_rechazados_lag_1"
# [521] "mcheques_emitidos_rechazados_delta_lag_1"
# [522] "mcheques_emitidos_rechazados_lag_2"
# [523] "mcheques_emitidos_rechazados_delta_lag_2"
# [524] "tcallcenter_lag_1"
# [525] "tcallcenter_delta_lag_1"
# [526] "tcallcenter_lag_2"
# [527] "tcallcenter_delta_lag_2"
# [528] "ccallcenter_transacciones_lag_1"
# [529] "ccallcenter_transacciones_delta_lag_1"
# [530] "ccallcenter_transacciones_lag_2"
# [531] "ccallcenter_transacciones_delta_lag_2"
# [532] "thomebanking_lag_1"
# [533] "thomebanking_delta_lag_1"
# [534] "thomebanking_lag_2"
# [535] "thomebanking_delta_lag_2"
# [536] "chomebanking_transacciones_lag_1"
# [537] "chomebanking_transacciones_delta_lag_1"
# [538] "chomebanking_transacciones_lag_2"
# [539] "chomebanking_transacciones_delta_lag_2"
# [540] "ccajas_transacciones_lag_1"
# [541] "ccajas_transacciones_delta_lag_1"
# [542] "ccajas_transacciones_lag_2"
# [543] "ccajas_transacciones_delta_lag_2"
# [544] "ccajas_consultas_lag_1"
# [545] "ccajas_consultas_delta_lag_1"
# [546] "ccajas_consultas_lag_2"
# [547] "ccajas_consultas_delta_lag_2"
# [548] "ccajas_depositos_lag_1"
# [549] "ccajas_depositos_delta_lag_1"
# [550] "ccajas_depositos_lag_2"
# [551] "ccajas_depositos_delta_lag_2"
# [552] "ccajas_extracciones_lag_1"
# [553] "ccajas_extracciones_delta_lag_1"
# [554] "ccajas_extracciones_lag_2"
# [555] "ccajas_extracciones_delta_lag_2"
# [556] "ccajas_otras_lag_1"
# [557] "ccajas_otras_delta_lag_1"
# [558] "ccajas_otras_lag_2"
# [559] "ccajas_otras_delta_lag_2"
# [560] "catm_trx_lag_1"
# [561] "catm_trx_delta_lag_1"
# [562] "catm_trx_lag_2"
# [563] "catm_trx_delta_lag_2"
# [564] "matm_lag_1"
# [565] "matm_delta_lag_1"
# [566] "matm_lag_2"
# [567] "matm_delta_lag_2"
# [568] "catm_trx_other_lag_1"
# [569] "catm_trx_other_delta_lag_1"
# [570] "catm_trx_other_lag_2"
# [571] "catm_trx_other_delta_lag_2"
# [572] "matm_other_lag_1"
# [573] "matm_other_delta_lag_1"
# [574] "matm_other_lag_2"
# [575] "matm_other_delta_lag_2"
# [576] "ctrx_quarter_lag_1"
# [577] "ctrx_quarter_delta_lag_1"
# [578] "ctrx_quarter_lag_2"
# [579] "ctrx_quarter_delta_lag_2"
# [580] "tmobile_app_lag_1"
# [581] "tmobile_app_delta_lag_1"
# [582] "tmobile_app_lag_2"
# [583] "tmobile_app_delta_lag_2"
# [584] "cmobile_app_trx_lag_1"
# [585] "cmobile_app_trx_delta_lag_1"
# [586] "cmobile_app_trx_lag_2"
# [587] "cmobile_app_trx_delta_lag_2"
# [588] "Master_delinquency_lag_1"
# [589] "Master_delinquency_delta_lag_1"
# [590] "Master_delinquency_lag_2"
# [591] "Master_delinquency_delta_lag_2"
# [592] "Master_status_lag_1"
# [593] "Master_status_delta_lag_1"
# [594] "Master_status_lag_2"
# [595] "Master_status_delta_lag_2"
# [596] "Master_mfinanciacion_limite_lag_1"
# [597] "Master_mfinanciacion_limite_delta_lag_1"
# [598] "Master_mfinanciacion_limite_lag_2"
# [599] "Master_mfinanciacion_limite_delta_lag_2"
# [600] "Master_Fvencimiento_lag_1"
# [601] "Master_Fvencimiento_delta_lag_1"
# [602] "Master_Fvencimiento_lag_2"
# [603] "Master_Fvencimiento_delta_lag_2"
# [604] "Master_Finiciomora_lag_1"
# [605] "Master_Finiciomora_delta_lag_1"
# [606] "Master_Finiciomora_lag_2"
# [607] "Master_Finiciomora_delta_lag_2"
# [608] "Master_msaldototal_lag_1"
# [609] "Master_msaldototal_delta_lag_1"
# [610] "Master_msaldototal_lag_2"
# [611] "Master_msaldototal_delta_lag_2"
# [612] "Master_msaldopesos_lag_1"
# [613] "Master_msaldopesos_delta_lag_1"
# [614] "Master_msaldopesos_lag_2"
# [615] "Master_msaldopesos_delta_lag_2"
# [616] "Master_msaldodolares_lag_1"
# [617] "Master_msaldodolares_delta_lag_1"
# [618] "Master_msaldodolares_lag_2"
# [619] "Master_msaldodolares_delta_lag_2"
# [620] "Master_mconsumospesos_lag_1"
# [621] "Master_mconsumospesos_delta_lag_1"
# [622] "Master_mconsumospesos_lag_2"
# [623] "Master_mconsumospesos_delta_lag_2"
# [624] "Master_mconsumosdolares_lag_1"
# [625] "Master_mconsumosdolares_delta_lag_1"
# [626] "Master_mconsumosdolares_lag_2"
# [627] "Master_mconsumosdolares_delta_lag_2"
# [628] "Master_mlimitecompra_lag_1"
# [629] "Master_mlimitecompra_delta_lag_1"
# [630] "Master_mlimitecompra_lag_2"
# [631] "Master_mlimitecompra_delta_lag_2"
# [632] "Master_madelantopesos_lag_1"
# [633] "Master_madelantopesos_delta_lag_1"
# [634] "Master_madelantopesos_lag_2"
# [635] "Master_madelantopesos_delta_lag_2"
# [636] "Master_madelantodolares_lag_1"
# [637] "Master_madelantodolares_delta_lag_1"
# [638] "Master_madelantodolares_lag_2"
# [639] "Master_madelantodolares_delta_lag_2"
# [640] "Master_fultimo_cierre_lag_1"
# [641] "Master_fultimo_cierre_delta_lag_1"
# [642] "Master_fultimo_cierre_lag_2"
# [643] "Master_fultimo_cierre_delta_lag_2"
# [644] "Master_mpagado_lag_1"
# [645] "Master_mpagado_delta_lag_1"
# [646] "Master_mpagado_lag_2"
# [647] "Master_mpagado_delta_lag_2"
# [648] "Master_mpagospesos_lag_1"
# [649] "Master_mpagospesos_delta_lag_1"
# [650] "Master_mpagospesos_lag_2"
# [651] "Master_mpagospesos_delta_lag_2"
# [652] "Master_mpagosdolares_lag_1"
# [653] "Master_mpagosdolares_delta_lag_1"
# [654] "Master_mpagosdolares_lag_2"
# [655] "Master_mpagosdolares_delta_lag_2"
# [656] "Master_fechaalta_lag_1"
# [657] "Master_fechaalta_delta_lag_1"
# [658] "Master_fechaalta_lag_2"
# [659] "Master_fechaalta_delta_lag_2"
# [660] "Master_mconsumototal_lag_1"
# [661] "Master_mconsumototal_delta_lag_1"
# [662] "Master_mconsumototal_lag_2"
# [663] "Master_mconsumototal_delta_lag_2"
# [664] "Master_cconsumos_lag_1"
# [665] "Master_cconsumos_delta_lag_1"
# [666] "Master_cconsumos_lag_2"
# [667] "Master_cconsumos_delta_lag_2"
# [668] "Master_cadelantosefectivo_lag_1"
# [669] "Master_cadelantosefectivo_delta_lag_1"
# [670] "Master_cadelantosefectivo_lag_2"
# [671] "Master_cadelantosefectivo_delta_lag_2"
# [672] "Master_mpagominimo_lag_1"
# [673] "Master_mpagominimo_delta_lag_1"
# [674] "Master_mpagominimo_lag_2"
# [675] "Master_mpagominimo_delta_lag_2"
# [676] "Visa_delinquency_lag_1"
# [677] "Visa_delinquency_delta_lag_1"
# [678] "Visa_delinquency_lag_2"
# [679] "Visa_delinquency_delta_lag_2"
# [680] "Visa_status_lag_1"
# [681] "Visa_status_delta_lag_1"
# [682] "Visa_status_lag_2"
# [683] "Visa_status_delta_lag_2"
# [684] "Visa_mfinanciacion_limite_lag_1"
# [685] "Visa_mfinanciacion_limite_delta_lag_1"
# [686] "Visa_mfinanciacion_limite_lag_2"
# [687] "Visa_mfinanciacion_limite_delta_lag_2"
# [688] "Visa_Fvencimiento_lag_1"
# [689] "Visa_Fvencimiento_delta_lag_1"
# [690] "Visa_Fvencimiento_lag_2"
# [691] "Visa_Fvencimiento_delta_lag_2"
# [692] "Visa_Finiciomora_lag_1"
# [693] "Visa_Finiciomora_delta_lag_1"
# [694] "Visa_Finiciomora_lag_2"
# [695] "Visa_Finiciomora_delta_lag_2"
# [696] "Visa_msaldototal_lag_1"
# [697] "Visa_msaldototal_delta_lag_1"
# [698] "Visa_msaldototal_lag_2"
# [699] "Visa_msaldototal_delta_lag_2"
# [700] "Visa_msaldopesos_lag_1"
# [701] "Visa_msaldopesos_delta_lag_1"
# [702] "Visa_msaldopesos_lag_2"
# [703] "Visa_msaldopesos_delta_lag_2"
# [704] "Visa_msaldodolares_lag_1"
# [705] "Visa_msaldodolares_delta_lag_1"
# [706] "Visa_msaldodolares_lag_2"
# [707] "Visa_msaldodolares_delta_lag_2"
# [708] "Visa_mconsumospesos_lag_1"
# [709] "Visa_mconsumospesos_delta_lag_1"
# [710] "Visa_mconsumospesos_lag_2"
# [711] "Visa_mconsumospesos_delta_lag_2"
# [712] "Visa_mconsumosdolares_lag_1"
# [713] "Visa_mconsumosdolares_delta_lag_1"
# [714] "Visa_mconsumosdolares_lag_2"
# [715] "Visa_mconsumosdolares_delta_lag_2"
# [716] "Visa_mlimitecompra_lag_1"
# [717] "Visa_mlimitecompra_delta_lag_1"
# [718] "Visa_mlimitecompra_lag_2"
# [719] "Visa_mlimitecompra_delta_lag_2"
# [720] "Visa_madelantopesos_lag_1"
# [721] "Visa_madelantopesos_delta_lag_1"
# [722] "Visa_madelantopesos_lag_2"
# [723] "Visa_madelantopesos_delta_lag_2"
# [724] "Visa_madelantodolares_lag_1"
# [725] "Visa_madelantodolares_delta_lag_1"
# [726] "Visa_madelantodolares_lag_2"
# [727] "Visa_madelantodolares_delta_lag_2"
# [728] "Visa_fultimo_cierre_lag_1"
# [729] "Visa_fultimo_cierre_delta_lag_1"
# [730] "Visa_fultimo_cierre_lag_2"
# [731] "Visa_fultimo_cierre_delta_lag_2"
# [732] "Visa_mpagado_lag_1"
# [733] "Visa_mpagado_delta_lag_1"
# [734] "Visa_mpagado_lag_2"
# [735] "Visa_mpagado_delta_lag_2"
# [736] "Visa_mpagospesos_lag_1"
# [737] "Visa_mpagospesos_delta_lag_1"
# [738] "Visa_mpagospesos_lag_2"
# [739] "Visa_mpagospesos_delta_lag_2"
# [740] "Visa_mpagosdolares_lag_1"
# [741] "Visa_mpagosdolares_delta_lag_1"
# [742] "Visa_mpagosdolares_lag_2"
# [743] "Visa_mpagosdolares_delta_lag_2"
# [744] "Visa_fechaalta_lag_1"
# [745] "Visa_fechaalta_delta_lag_1"
# [746] "Visa_fechaalta_lag_2"
# [747] "Visa_fechaalta_delta_lag_2"
# [748] "Visa_mconsumototal_lag_1"
# [749] "Visa_mconsumototal_delta_lag_1"
# [750] "Visa_mconsumototal_lag_2"
# [751] "Visa_mconsumototal_delta_lag_2"
# [752] "Visa_cconsumos_lag_1"
# [753] "Visa_cconsumos_delta_lag_1"
# [754] "Visa_cconsumos_lag_2"
# [755] "Visa_cconsumos_delta_lag_2"
# [756] "Visa_cadelantosefectivo_lag_1"
# [757] "Visa_cadelantosefectivo_delta_lag_1"
# [758] "Visa_cadelantosefectivo_lag_2"
# [759] "Visa_cadelantosefectivo_delta_lag_2"
# [760] "Visa_mpagominimo_lag_1"
# [761] "Visa_mpagominimo_delta_lag_1"
# [762] "Visa_mpagominimo_lag_2"
# [763] "Visa_mpagominimo_delta_lag_2"

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in%  PARAM$train &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 17964
# [1] 762

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Fri Oct 10 09:30:25 PM 2025 AUC 0.906864375689639
#
# [mbo] 28: num_iterations=2017; learning_rate=0.0116; feature_fraction=0.998; num_leaves=2037; min_data_in_leaf=3300 : y = 0.907 : 31.5 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Fri Oct 10 09:31:36 PM 2025 AUC 0.921161261337226
#
# [mbo] 29: num_iterations=1536; learning_rate=0.14; feature_fraction=0.388; num_leaves=619; min_data_in_leaf=161 : y = 0.921 : 71.2 secs : infill_ei
#
# Fri Oct 10 09:32:16 PM 2025 AUC 0.924622934656735
#
# [mbo] 30: num_iterations=1385; learning_rate=0.0105; feature_fraction=0.472; num_leaves=12; min_data_in_leaf=487 : y = 0.925 : 39.4 secs : infill_ei
#
# Fri Oct 10 09:32:25 PM 2025 AUC 0.915950668994693
#
# [mbo] 31: num_iterations=443; learning_rate=0.298; feature_fraction=0.707; num_leaves=2047; min_data_in_leaf=2068 : y = 0.916 : 8.3 secs : infill_ei
#
# Fri Oct 10 09:33:08 PM 2025 AUC 0.92076257074579
#
# [mbo] 32: num_iterations=2045; learning_rate=0.281; feature_fraction=0.99; num_leaves=9; min_data_in_leaf=483 : y = 0.921 : 42.9 secs : infill_ei
#
# Fri Oct 10 09:33:30 PM 2025 AUC 0.880476392834944
#
# [mbo] 33: num_iterations=2048; learning_rate=0.0242; feature_fraction=0.996; num_leaves=965; min_data_in_leaf=6569 : y = 0.88 : 21.2 secs : infill_ei
#
# Fri Oct 10 09:33:46 PM 2025 AUC 0.914283478019209
#
# [mbo] 34: num_iterations=384; learning_rate=0.297; feature_fraction=0.103; num_leaves=2009; min_data_in_leaf=196 : y = 0.914 : 15.6 secs : infill_ei
#
# Fri Oct 10 09:34:09 PM 2025 AUC 0.91302830555033
#
# [mbo] 35: num_iterations=1192; learning_rate=0.268; feature_fraction=0.16; num_leaves=2046; min_data_in_leaf=2428 : y = 0.913 : 23.4 secs : infill_ei
#
# Fri Oct 10 09:34:59 PM 2025 AUC 0.917384626736595
#
# [mbo] 36: num_iterations=2041; learning_rate=0.298; feature_fraction=0.598; num_leaves=2037; min_data_in_leaf=1569 : y = 0.917 : 49.1 secs : infill_ei
#
# Fri Oct 10 09:35:13 PM 2025 AUC 0.911523109385286
#
# [mbo] 37: num_iterations=901; learning_rate=0.0119; feature_fraction=0.992; num_leaves=2034; min_data_in_leaf=2334 : y = 0.912 : 14.0 secs : infill_ei
#
# Fri Oct 10 09:35:14 PM 2025 AUC 0.90711454594793
#
# [mbo] 38: num_iterations=19; learning_rate=0.0103; feature_fraction=0.229; num_leaves=16; min_data_in_leaf=13 : y = 0.907 : 0.9 secs : infill_ei
#
# Fri Oct 10 09:35:16 PM 2025 AUC 0.897797067722777
#
# [mbo] 39: num_iterations=29; learning_rate=0.297; feature_fraction=0.998; num_leaves=2043; min_data_in_leaf=3154 : y = 0.898 : 1.0 secs : infill_ei
#
# Fri Oct 10 09:35:49 PM 2025 AUC 0.92245288911483
#
# [mbo] 40: num_iterations=1549; learning_rate=0.01; feature_fraction=1; num_leaves=2032; min_data_in_leaf=1230 : y = 0.922 : 33.2 secs : infill_ei
#
# Fri Oct 10 09:36:48 PM 2025 AUC 0.92487889224601
#
# [mbo] 41: num_iterations=2037; learning_rate=0.0225; feature_fraction=0.159; num_leaves=81; min_data_in_leaf=350 : y = 0.925 : 58.2 secs : infill_ei
#
# Fri Oct 10 09:37:15 PM 2025 AUC 0.919286866453842
#
# [mbo] 42: num_iterations=986; learning_rate=0.298; feature_fraction=0.557; num_leaves=8; min_data_in_leaf=385 : y = 0.919 : 26.4 secs : infill_ei
#
# Fri Oct 10 09:37:32 PM 2025 AUC 0.915262897102338
#
# [mbo] 43: num_iterations=841; learning_rate=0.0102; feature_fraction=0.994; num_leaves=16; min_data_in_leaf=1940 : y = 0.915 : 16.9 secs : infill_ei
#
# Fri Oct 10 09:38:13 PM 2025 AUC 0.914065137173433
#
# [mbo] 44: num_iterations=1689; learning_rate=0.3; feature_fraction=0.405; num_leaves=1029; min_data_in_leaf=2095 : y = 0.914 : 40.5 secs : infill_ei
#
# Fri Oct 10 09:38:56 PM 2025 AUC 0.919012754359589
#
# [mbo] 45: num_iterations=2028; learning_rate=0.01; feature_fraction=0.102; num_leaves=1394; min_data_in_leaf=1484 : y = 0.919 : 42.8 secs : infill_ei
#
# Fri Oct 10 09:39:09 PM 2025 AUC 0.895739991276035
#
# [mbo] 46: num_iterations=897; learning_rate=0.263; feature_fraction=0.842; num_leaves=2045; min_data_in_leaf=5081 : y = 0.896 : 12.2 secs : infill_ei
#
# Fri Oct 10 09:39:43 PM 2025 AUC 0.906939822612764
#
# [mbo] 47: num_iterations=2048; learning_rate=0.174; feature_fraction=0.1; num_leaves=2032; min_data_in_leaf=3528 : y = 0.907 : 34.3 secs : infill_ei
#
# Fri Oct 10 09:40:13 PM 2025 AUC 0.903732391152531
#
# [mbo] 48: num_iterations=2046; learning_rate=0.0256; feature_fraction=0.654; num_leaves=8; min_data_in_leaf=3600 : y = 0.904 : 28.8 secs : infill_ei
#
# Fri Oct 10 09:40:48 PM 2025 AUC 0.923245576953248
#
# [mbo] 49: num_iterations=1472; learning_rate=0.0757; feature_fraction=0.101; num_leaves=2013; min_data_in_leaf=528 : y = 0.923 : 34.5 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Fri Oct 10 09:41:36 PM 2025 AUC 0.924073091955897
#
# [mbo] 50: num_iterations=1994; learning_rate=0.0106; feature_fraction=0.999; num_leaves=257; min_data_in_leaf=1045 : y = 0.924 : 47.8 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1337    0.07250005        0.1015656         12              215
# [1] 0.9268246

# %% [markdown]
# ## Para el resto de las semillas, comenté toda la parte de optimizacion bayesiana y deje el siguiente bloque de código:

# %%
# mejores_params_obtenidos <- list(
#     num_iterations = 1337L,
#     learning_rate = 0.07250005,
#     feature_fraction = 0.1015656,
#     num_leaves = 12L,
#     min_data_in_leaf = 215
# )

# PARAM$out$lgbm$mejores_hiperparametros <- as.data.table(mejores_params_obtenidos)

# %%
#con este codigo verifico la salida en cada interaccion
message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la  optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 CONTINUA       642824
# 2 BAJA+2           3938
# 3 BAJA+1           3447

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 202513
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1337
#
# $learning_rate
# [1] 0.07250005
#
# $feature_fraction
# [1] 0.1015656
#
# $num_leaves
# [1] 12
#
# $min_data_in_leaf
# [1] 215

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria y mucho menos cross validation.

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# entreno LightGBM

modelo_final <- lgb.train(
  data= dtrain_final,
  param= param_normalizado
)

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...
lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes %in% PARAM$future]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %%
# inicilizo el dataset  drealidad
drealidad <- realidad_inicializar( dfuture, PARAM)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
PARAM$cortes
# Out:
# [1] 10000 10500 11000 11500 12000

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  res <- realidad_evaluar( drealidad, tb_prediccion)

  options(scipen = 999)
  cat( "Envios=", envios, "\t",
    " TOTAL=", res$total,
    "  Public=", res$public,
    " Private=", res$private,
    "\n",
    sep= ""
  )

}
# Out:
# Envios=10000	 TOTAL=-200000000  Public=-203933333 Private=-198314286
# Envios=10500	 TOTAL=-210000000  Public=-214133333 Private=-208228571
# Envios=11000	 TOTAL=-220000000  Public=-222400000 Private=-218971429
# Envios=11500	 TOTAL=-230000000  Public=-232600000 Private=-228885714
# Envios=12000	 TOTAL=-240000000  Public=-242666667 Private=-238857143

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Oct 10 09:44:04 PM 2025"
